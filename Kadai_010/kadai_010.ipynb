# %%
# 消費税を加えた計算結果を返す関数
def calculate_tax(price, tax_rate):
    # 消費税額を計算して金額に足す
    total_price = price + (price * (tax_rate / 100))
    return total_price

# 関数の呼び出し（第1引数: 110, 第2引数: 10）
result = calculate_tax(110, 10)

# 結果の出力
print(result)
# Out:
# 121.0
